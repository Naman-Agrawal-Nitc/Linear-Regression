# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
salary_data=pd.read_csv('test.csv')
x=salary_data.iloc[:,:-1].values
y=salary_data.iloc[:,1].values

# %%
sns.distplot(salary_data['y'],kde=False,bins=10)

sns.distplot(salary_data['x'],kde=False,bins=10)

# %%
sns.heatmap(salary_data.corr())

# %%
sns.barplot(x='x',y='y',data=salary_data)

# %%
sns.countplot(y='y',data=salary_data)

# %%
from sklearn.model_selection import train_test_split
x_train , x_test, y_train ,y_test =train_test_split(x, y,test_size=1/3 ,random_state=0)

# %%
x_test
# Out:
# array([[ 67],
#        [ 27],
#        [ 96],
#        [100],
#        [ 28],
#        [ 65],
#        [ 37],
#        [ 40],
#        [ 52],
#        [ 89],
#        [ 92],
#        [ 15],
#        [ 37],
#        [ 90],
#        [ 89],
#        [ 15],
#        [ 55],
#        [ 67],
#        [ 14],
#        [ 49],
#        [ 92],
#        [ 74],
#        [ 41],
#        [ 29],
#        [ 48],
#        [ 17],
#        [ 61],
#        [ 16],
#        [ 65],
#        [ 71],
#        [ 63],
#        [ 41],
#        [ 20],
#        [ 98],
#        [  4],
#        [ 60],
#        [ 58],
#        [ 93],
#        [ 47],
#        [ 15],
#        [ 42],
#        [ 43],
#        [ 27],
#        [ 28],
#        [  0],
#        [ 53],
#        [ 56],
#        [ 82],
#        [ 95],
#        [ 37],
#        [ 53],
#        [ 44],
#        [ 56],
#        [  1],
#        [ 57],
#        [ 60],
#        [ 21],
#        [ 79],
#        [ 59],
#        [ 84],
#        [ 28],
#        [ 63],
#        [ 61],
#        [  1],
#        [ 19],
#        [ 96],
#        [ 56],
#        [ 16],
#        [ 89],
#        [ 70],
#        [ 81],
#        [ 14],
#        [ 72],
#        [ 21],
#        [ 12],
#        [ 36],
#        [ 69],
#        [ 87],
#        [ 73],
#        [ 30],
#        [ 13],
#        [ 42],
#        [ 57],
#        [ 23],
#        [  5],
#        [ 81],
#        [ 59],
#        [ 39],
#        [ 78],
#        [ 16],
#        [ 64],
#        [  4],
#        [ 56],
#        [ 46],
#        [ 94],
#        [ 33],
#        [ 82],
#        [ 59],
#        [ 97],
#        [ 87]], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([ 67.38902654,  27.24459126,  96.49374212, 100.50818565,
#         28.24820214,  65.38180478,  37.28070008,  40.29153272,
#         52.33486331,  89.46846594,  92.47929859,  15.20126067,
#         37.28070008,  90.47207683,  89.46846594,  15.20126067,
#         55.34569596,  67.38902654,  14.19764979,  49.32403066,
#         92.47929859,  74.41430271,  41.29514361,  29.25181302,
#         48.32041978,  17.20848244,  61.36736125,  16.20487156,
#         65.38180478,  71.40347007,  63.37458301,  41.29514361,
#         20.21931508,  98.50096388,   4.16154097,  60.36375037,
#         58.3565286 ,  93.48290947,  47.3168089 ,  15.20126067,
#         42.29875449,  43.30236537,  27.24459126,  28.24820214,
#          0.14709744,  53.33847419,  56.34930684,  82.44318977,
#         95.49013124,  37.28070008,  53.33847419,  44.30597625,
#         56.34930684,   1.15070832,  57.35291772,  60.36375037,
#         21.22292597,  79.43235712,  59.36013948,  84.45041153,
#         28.24820214,  63.37458301,  61.36736125,   1.15070832,
#         19.2157042 ,  96.49374212,  56.34930684,  16.20487156,
#         89.46846594,  70.39985919,  81.43957889,  14.19764979,
#         72.40708095,  21.22292597,  12.19042803,  36.2770892 ,
#         69.3962483 ,  87.46124418,  73.41069183,  30.2554239 ,
#         13.19403891,  42.29875449,  57.35291772,  23.23014773,
#          5.16515185,  81.43957889,  59.36013948,  39.28792184,
#         78.42874624,  16.20487156,  64.37819389,   4.16154097,
#         56.34930684,  46.31319802,  94.48652036,  33.26625655,
#         82.44318977,  59.36013948,  97.497353  ,  87.46124418])

# %%
y_test
# Out:
# array([ 68.48820749,  30.49412933,  95.14907176, 103.5266162 ,
#         28.15668543,  68.94699774,  40.00709598,  48.09843134,
#         54.08170635,  87.45721555,  91.30863673,  14.82248589,
#         34.12473248,  89.899991  ,  89.82634442,  13.25690647,
#         55.81628509,  67.02150613,  12.42624606,  52.28620611,
#         89.73153611,  75.69298554,  45.44599591,  26.49487961,
#         47.41006725,  13.41310757,  60.07137496,  16.74923937,
#         66.61499643,  68.5458879 ,  58.61466887,  38.68888682,
#         18.39512747,  95.58017185,   7.64652976,  59.8313966 ,
#         57.48741435,  99.43577876,  52.45946688,   9.80523488,
#         42.03835773,  48.67252645,  23.44479161,  33.07112825,
#          1.04011421,  60.20758349,  57.19103506,  85.45504157,
#         97.61793701,  36.11334779,  50.17008622,  45.96396877,
#         54.55446979,   0.27530726,  56.14834113,  60.11134958,
#         18.98322306,  78.31056542,  60.91792707,  85.18657275,
#         29.31770045,  63.28312382,  59.225745  ,   5.3136862 ,
#         14.99514319,  96.11982476,  61.09367762,  16.68715211,
#         92.11906278,  67.2352155 ,  78.79008525,  15.49301141,
#         77.9969477 ,  19.1315097 ,  12.11219941,  38.67780759,
#         69.46306072,  84.06676818,  72.86282528,  26.48713683,
#          9.74416426,  38.98317436,  51.57326718,  23.52647153,
#          0.67607675,  73.9308764 ,  62.22635684,  38.05766408,
#         81.40381769,  11.21710477,  67.68142149,   5.60766487,
#         56.01448111,  48.35172635,  97.00148372,  30.48881287,
#         88.54475895,  59.61247085, 101.0697879 ,  90.65513736])

# %%
plt.scatter(x_train,y_train,color='blue')
plt.plot(x_train,lr.predict(x_train),color='red')
plt.show()

# %%
plt.scatter(x_test,y_test,color='blue')
plt.plot(x_test,y_pred,color='red')
plt.show()

# %%
from sklearn import metrics
print(metrics.mean_absolute_error(y_test,y_pred))
print(metrics.mean_squared_error(y_test,y_pred))
print(np.sqrt(metrics.mean_absolute_error(y_test,y_pred)))
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 2.460630734257702
# 9.27919185458209
# 1.56863977198645
# 3.0461765960925655
